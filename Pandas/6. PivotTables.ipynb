# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Pivot Tables

# %%
data = {
    'Date': pd.date_range('2026-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)
df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2026-01-01       A   East    522     24   John  January      Q1
# 1  2026-01-02       B   West    330     62   Mary  January      Q1
# 2  2026-01-03       C  North    506     69    Bob  January      Q1
# 3  2026-01-04       D  South    114     99  Alice  January      Q1
# 4  2026-01-05       A   East    334     36   John  January      Q1
# 5  2026-01-06       B   West    163     82   Mary  January      Q1
# 6  2026-01-07       C  North    806     12    Bob  January      Q1
# 7  2026-01-08       D  South    923     61  Alice  January      Q1
# 8  2026-01-09       A   East    891     31   John  January      Q1
# 9  2026-01-10       B   West    485     75   Mary  January      Q1
# 10 2026-01-11       C  North    403     26    Bob  January      Q1
# 11 2026-01-12       D  South    786     93  Alice  January      Q1
# 12 2026-01-13       A   East    552     15   John  January      Q1
# 13 2026-01-14       B   West    374     27   Mary  January      Q1
# 14 2026-01-15       C  North    538     29    Bob  January      Q1
# 15 2026-01-16       D  South    816     65  Alice  January      Q1
# 16 2026-01-17       A   East    851     23   John  January      Q1
# 17 2026-01-18       B   West    472     40   Mary  January      Q1
# 18 2026-01-19       C  North    211     74    Bob  January      Q1
# 19 2026-01-20       D  South    761     72  Alice  January      Q1

# %%
pd.pivot_table(df,values="Sales", index='Region', columns="Product", aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     552.0    NaN    NaN    NaN
# North      NaN    NaN  506.0    NaN
# South      NaN    NaN    NaN  786.0
# West       NaN  374.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     630.0    NaN    NaN    NaN  25.8   NaN   NaN   NaN
# North      NaN    NaN  492.8    NaN   NaN   NaN  42.0   NaN
# South      NaN    NaN    NaN  680.0   NaN   NaN   NaN  78.0
# West       NaN  364.8    NaN    NaN   NaN  57.2   NaN   NaN

# %% [markdown]
# ### Cross Tabs

# %%
pd.crosstab(df['Region'], df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
